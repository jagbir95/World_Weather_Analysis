# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#coordinates

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 612

# %%
#declare the url
url="https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid="+weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | nanortalik
# Processing Record 5 of Set 1 | mankono
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | zemio
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | codrington
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | port shepstone
# Processing Record 14 of Set 1 | conde
# Processing Record 15 of Set 1 | ulaangom
# Processing Record 16 of Set 1 | novosil
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | chuy
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | narsaq
# Processing Record 23 of Set 1 | tucupita
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | san quintin
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 29 of Set 1 | lensk
# Processing Record 30 of Set 1 | maarianhamina
# Processing Record 31 of Set 1 | grindavik
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | aykhal
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | wattegama
# Processing Record 37 of Set 1 | emba
# Processing Record 38 of Set 1 | bambous virieux
# Processing Record 39 of Set 1 | bassano
# Processing Record 40 of Set 1 | constitucion
# Processing Record 41 of Set 1 | wanning
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | zabol
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | severo-kurilsk
# Processing Record 47 of Set 1 | broken hill
# Processing Record 48 of Set 1 | mayo
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | katsuura
# Processing Record 2 of Set 2 | samarai
# Processing Record 3 of Set 2 | faya
# Processing Record 4 of Set 2 | kempten
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | dengzhou
# Processing Record 7 of Set 2 | champerico
# Processing Record 8 of Set 2 | kulhudhuffushi
# Processing Record 9 of Set 2 | saint george
# Processing Record 10 of Set 2 | pisco
# Processing Record 11 of Set 2 | jalu
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | boyolangu
# Processing Record 14 of Set 2 | touros
# Processing Record 15 of Set 2 | gladstone
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | chokurdakh
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | souillac
# Processing Record 20 of Set 2 | goundi
# Processing Record 21 of Set 2 | tautira
# Processing Record 22 of Set 2 | ambilobe
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | salalah
# Processing Record 25 of Set 2 | east london
# Processing Record 26 of Set 2 | bara
# Processing Record 27 of Set 2 | seydi
# Processing Record 28 of Set 2 | taburi
# City not found. Skipping...
# Processing Record 29 of Set 2 | ulladulla
# Processing Record 30 of Set 2 | khatanga
# Processing Record 31 of Set 2 | luderitz
# Processing Record 32 of Set 2 | leningradskiy
# Processing Record 33 of Set 2 | vardo
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | meulaboh
# Processing Record 37 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 2 | sukhumi
# Processing Record 40 of Set 2 | nogales
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | santa rosa
# Processing Record 43 of Set 2 | svetlogorsk
# Processing Record 44 of Set 2 | minas
# Processing Record 45 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 2 | dunedin
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | chapais
# Processing Record 49 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 2 | dikson
# Processing Record 1 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 3 | karratha
# Processing Record 5 of Set 3 | moron
# Processing Record 6 of Set 3 | svetlaya
# Processing Record 7 of Set 3 | qaanaaq
# Processing Record 8 of Set 3 | coahuayana
# Processing Record 9 of Set 3 | hilo
# Processing Record 10 of Set 3 | srednekolymsk
# Processing Record 11 of Set 3 | atambua
# Processing Record 12 of Set 3 | tuktoyaktuk
# Processing Record 13 of Set 3 | los llanos de aridane
# Processing Record 14 of Set 3 | callaguip
# Processing Record 15 of Set 3 | dingle
# Processing Record 16 of Set 3 | fort nelson
# Processing Record 17 of Set 3 | provideniya
# Processing Record 18 of Set 3 | mount gambier
# Processing Record 19 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 3 | bethel
# Processing Record 21 of Set 3 | acapulco
# Processing Record 22 of Set 3 | emerald
# Processing Record 23 of Set 3 | san patricio
# Processing Record 24 of Set 3 | guayaramerin
# Processing Record 25 of Set 3 | valley station
# Processing Record 26 of Set 3 | taguatinga
# Processing Record 27 of Set 3 | vila franca do campo
# Processing Record 28 of Set 3 | padang
# Processing Record 29 of Set 3 | castro
# Processing Record 30 of Set 3 | olga
# Processing Record 31 of Set 3 | bani
# Processing Record 32 of Set 3 | karatau
# Processing Record 33 of Set 3 | thompson
# Processing Record 34 of Set 3 | broome
# Processing Record 35 of Set 3 | zhuhai
# Processing Record 36 of Set 3 | alta floresta
# Processing Record 37 of Set 3 | retz
# Processing Record 38 of Set 3 | mayumba
# Processing Record 39 of Set 3 | kenai
# Processing Record 40 of Set 3 | coihueco
# Processing Record 41 of Set 3 | seoul
# Processing Record 42 of Set 3 | nanakuli
# Processing Record 43 of Set 3 | laguna
# Processing Record 44 of Set 3 | champua
# Processing Record 45 of Set 3 | nizhniy kuranakh
# Processing Record 46 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 3 | punta arenas
# Processing Record 48 of Set 3 | dicabisagan
# Processing Record 49 of Set 3 | shache
# Processing Record 50 of Set 3 | bawal
# Processing Record 1 of Set 4 | flinders
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 4 | namatanai
# Processing Record 5 of Set 4 | beringovskiy
# Processing Record 6 of Set 4 | dongning
# Processing Record 7 of Set 4 | nantucket
# Processing Record 8 of Set 4 | tshikapa
# Processing Record 9 of Set 4 | starkville
# Processing Record 10 of Set 4 | zhigansk
# Processing Record 11 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 4 | krasnoarmeysk
# Processing Record 13 of Set 4 | lethem
# Processing Record 14 of Set 4 | kerouane
# Processing Record 15 of Set 4 | clyde river
# Processing Record 16 of Set 4 | college
# Processing Record 17 of Set 4 | teknaf
# Processing Record 18 of Set 4 | iquitos
# Processing Record 19 of Set 4 | kapaa
# Processing Record 20 of Set 4 | vao
# Processing Record 21 of Set 4 | marilia
# Processing Record 22 of Set 4 | puerto escondido
# Processing Record 23 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 4 | tabas
# Processing Record 25 of Set 4 | carnarvon
# Processing Record 26 of Set 4 | ponta delgada
# Processing Record 27 of Set 4 | plettenberg bay
# Processing Record 28 of Set 4 | zhanaozen
# Processing Record 29 of Set 4 | smirnykh
# Processing Record 30 of Set 4 | gulshat
# City not found. Skipping...
# Processing Record 31 of Set 4 | sulangan
# Processing Record 32 of Set 4 | kremenchuk
# Processing Record 33 of Set 4 | kamaishi
# Processing Record 34 of Set 4 | torbay
# Processing Record 35 of Set 4 | tigil
# Processing Record 36 of Set 4 | villarrica
# Processing Record 37 of Set 4 | new norfolk
# Processing Record 38 of Set 4 | camocim
# Processing Record 39 of Set 4 | sao joao da barra
# Processing Record 40 of Set 4 | ostrovnoy
# Processing Record 41 of Set 4 | severnoye
# Processing Record 42 of Set 4 | russell
# Processing Record 43 of Set 4 | cilegon
# Processing Record 44 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 4 | bogotol
# Processing Record 46 of Set 4 | sal rei
# Processing Record 47 of Set 4 | jamestown
# Processing Record 48 of Set 4 | nuuk
# Processing Record 49 of Set 4 | chaochou
# City not found. Skipping...
# Processing Record 50 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 5 | vanavara
# Processing Record 2 of Set 5 | puerto rico
# Processing Record 3 of Set 5 | langenburg
# Processing Record 4 of Set 5 | torres
# Processing Record 5 of Set 5 | mahebourg
# Processing Record 6 of Set 5 | san juan del sur
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | ornskoldsvik
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | esperance
# Processing Record 11 of Set 5 | pitimbu
# Processing Record 12 of Set 5 | tvoroyri
# Processing Record 13 of Set 5 | bereda
# Processing Record 14 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 5 | lisakovsk
# Processing Record 16 of Set 5 | caravelas
# Processing Record 17 of Set 5 | bartica
# Processing Record 18 of Set 5 | bobo dioulasso
# Processing Record 19 of Set 5 | kahului
# Processing Record 20 of Set 5 | cherskiy
# Processing Record 21 of Set 5 | micheweni
# Processing Record 22 of Set 5 | cheyenne
# Processing Record 23 of Set 5 | fortuna
# Processing Record 24 of Set 5 | cao bang
# Processing Record 25 of Set 5 | nemuro
# Processing Record 26 of Set 5 | olafsvik
# Processing Record 27 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 5 | haines junction
# Processing Record 29 of Set 5 | ara
# Processing Record 30 of Set 5 | saraland
# Processing Record 31 of Set 5 | canberra
# Processing Record 32 of Set 5 | youkounkoun
# Processing Record 33 of Set 5 | cabo san lucas
# Processing Record 34 of Set 5 | galveston
# Processing Record 35 of Set 5 | cayenne
# Processing Record 36 of Set 5 | pyapon
# Processing Record 37 of Set 5 | bonnyville
# Processing Record 38 of Set 5 | verkhnyaya inta
# Processing Record 39 of Set 5 | urucara
# Processing Record 40 of Set 5 | oksbol
# Processing Record 41 of Set 5 | coihaique
# Processing Record 42 of Set 5 | talnakh
# Processing Record 43 of Set 5 | puerto ayacucho
# Processing Record 44 of Set 5 | ndjole
# Processing Record 45 of Set 5 | faanui
# Processing Record 46 of Set 5 | abha
# Processing Record 47 of Set 5 | iranshahr
# Processing Record 48 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 5 | jinzhou
# Processing Record 50 of Set 5 | kolokani
# Processing Record 1 of Set 6 | te anau
# Processing Record 2 of Set 6 | dinguiraye
# Processing Record 3 of Set 6 | kemijarvi
# Processing Record 4 of Set 6 | bobonong
# City not found. Skipping...
# Processing Record 5 of Set 6 | kaitangata
# Processing Record 6 of Set 6 | snezhnogorsk
# Processing Record 7 of Set 6 | gudalur
# Processing Record 8 of Set 6 | ismailia
# Processing Record 9 of Set 6 | boddam
# Processing Record 10 of Set 6 | tilichiki
# Processing Record 11 of Set 6 | stokmarknes
# Processing Record 12 of Set 6 | fare
# Processing Record 13 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 14 of Set 6 | asau
# Processing Record 15 of Set 6 | sorong
# Processing Record 16 of Set 6 | chaa-khol
# City not found. Skipping...
# Processing Record 17 of Set 6 | victoria
# Processing Record 18 of Set 6 | kimbe
# Processing Record 19 of Set 6 | mongu
# Processing Record 20 of Set 6 | tuatapere
# Processing Record 21 of Set 6 | sao filipe
# Processing Record 22 of Set 6 | alofi
# Processing Record 23 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 6 | biak
# Processing Record 25 of Set 6 | ganta
# Processing Record 26 of Set 6 | suntar
# Processing Record 27 of Set 6 | wanaka
# Processing Record 28 of Set 6 | isangel
# Processing Record 29 of Set 6 | daru
# Processing Record 30 of Set 6 | birao
# Processing Record 31 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 6 | richards bay
# Processing Record 33 of Set 6 | vestmannaeyjar
# Processing Record 34 of Set 6 | roma
# Processing Record 35 of Set 6 | buchanan
# Processing Record 36 of Set 6 | airai
# Processing Record 37 of Set 6 | vestmanna
# Processing Record 38 of Set 6 | vulcan
# Processing Record 39 of Set 6 | okhotsk
# Processing Record 40 of Set 6 | lompoc
# Processing Record 41 of Set 6 | sibolga
# Processing Record 42 of Set 6 | nsanje
# Processing Record 43 of Set 6 | acarau
# Processing Record 44 of Set 6 | bath
# Processing Record 45 of Set 6 | komsomolskiy
# Processing Record 46 of Set 6 | charters towers
# Processing Record 47 of Set 6 | mana
# Processing Record 48 of Set 6 | coquimbo
# Processing Record 49 of Set 6 | odweyne
# Processing Record 50 of Set 6 | sayyan
# Processing Record 1 of Set 7 | iqaluit
# Processing Record 2 of Set 7 | ancud
# Processing Record 3 of Set 7 | paita
# Processing Record 4 of Set 7 | port lincoln
# Processing Record 5 of Set 7 | cartagena
# Processing Record 6 of Set 7 | bathsheba
# Processing Record 7 of Set 7 | filingue
# Processing Record 8 of Set 7 | gairo
# Processing Record 9 of Set 7 | churapcha
# Processing Record 10 of Set 7 | lubumbashi
# Processing Record 11 of Set 7 | turukhansk
# Processing Record 12 of Set 7 | hamilton
# Processing Record 13 of Set 7 | kapoeta
# Processing Record 14 of Set 7 | ixtapa
# Processing Record 15 of Set 7 | envira
# Processing Record 16 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 7 | tazovskiy
# Processing Record 19 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 20 of Set 7 | bogale
# Processing Record 21 of Set 7 | huixtla
# Processing Record 22 of Set 7 | benicarlo
# Processing Record 23 of Set 7 | xiongzhou
# Processing Record 24 of Set 7 | riyadh
# Processing Record 25 of Set 7 | kailua
# Processing Record 26 of Set 7 | ushtobe
# Processing Record 27 of Set 7 | nikolskoye
# Processing Record 28 of Set 7 | paamiut
# Processing Record 29 of Set 7 | vero beach
# Processing Record 30 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 31 of Set 7 | atar
# Processing Record 32 of Set 7 | sidrolandia
# Processing Record 33 of Set 7 | bima
# Processing Record 34 of Set 7 | deputatskiy
# Processing Record 35 of Set 7 | fukue
# Processing Record 36 of Set 7 | erzin
# Processing Record 37 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 7 | longyearbyen
# Processing Record 39 of Set 7 | elmira
# Processing Record 40 of Set 7 | hervey bay
# Processing Record 41 of Set 7 | kruisfontein
# Processing Record 42 of Set 7 | sola
# Processing Record 43 of Set 7 | pioner
# Processing Record 44 of Set 7 | razole
# Processing Record 45 of Set 7 | el rosario
# Processing Record 46 of Set 7 | gardan diwal
# City not found. Skipping...
# Processing Record 47 of Set 7 | saldanha
# Processing Record 48 of Set 7 | taburao
# City not found. Skipping...
# Processing Record 49 of Set 7 | adrar
# Processing Record 50 of Set 7 | nadlac
# Processing Record 1 of Set 8 | ceres
# Processing Record 2 of Set 8 | the hammocks
# Processing Record 3 of Set 8 | buraydah
# Processing Record 4 of Set 8 | saint-pierre
# Processing Record 5 of Set 8 | kjollefjord
# Processing Record 6 of Set 8 | trairi
# Processing Record 7 of Set 8 | vicuna
# Processing Record 8 of Set 8 | pevek
# Processing Record 9 of Set 8 | sept-iles
# Processing Record 10 of Set 8 | tahta
# Processing Record 11 of Set 8 | palatka
# Processing Record 12 of Set 8 | goderich
# Processing Record 13 of Set 8 | lorengau
# Processing Record 14 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 8 | beian
# Processing Record 16 of Set 8 | road town
# Processing Record 17 of Set 8 | guerrero negro
# Processing Record 18 of Set 8 | cap-aux-meules
# Processing Record 19 of Set 8 | roald
# Processing Record 20 of Set 8 | sungaipenuh
# Processing Record 21 of Set 8 | lata
# Processing Record 22 of Set 8 | gravdal
# Processing Record 23 of Set 8 | teya
# Processing Record 24 of Set 8 | gamba
# Processing Record 25 of Set 8 | ribeira grande
# Processing Record 26 of Set 8 | dzerzhinskoye
# Processing Record 27 of Set 8 | sault sainte marie
# Processing Record 28 of Set 8 | kayerkan
# Processing Record 29 of Set 8 | batticaloa
# Processing Record 30 of Set 8 | northam
# Processing Record 31 of Set 8 | flin flon
# Processing Record 32 of Set 8 | kizukuri
# Processing Record 33 of Set 8 | kidal
# Processing Record 34 of Set 8 | behshahr
# Processing Record 35 of Set 8 | jhalida
# Processing Record 36 of Set 8 | parras
# City not found. Skipping...
# Processing Record 37 of Set 8 | surab
# Processing Record 38 of Set 8 | pak phanang
# Processing Record 39 of Set 8 | manokwari
# Processing Record 40 of Set 8 | milford
# Processing Record 41 of Set 8 | baker city
# Processing Record 42 of Set 8 | ravar
# Processing Record 43 of Set 8 | bereznik
# Processing Record 44 of Set 8 | kirensk
# Processing Record 45 of Set 8 | uyskoye
# Processing Record 46 of Set 8 | denpasar
# Processing Record 47 of Set 8 | jizan
# Processing Record 48 of Set 8 | ahipara
# Processing Record 49 of Set 8 | mohpa
# Processing Record 50 of Set 8 | westport
# Processing Record 1 of Set 9 | umm lajj
# Processing Record 2 of Set 9 | vicosa
# Processing Record 3 of Set 9 | hobyo
# Processing Record 4 of Set 9 | hammerfest
# Processing Record 5 of Set 9 | la plata
# Processing Record 6 of Set 9 | goroka
# Processing Record 7 of Set 9 | port hedland
# Processing Record 8 of Set 9 | alice springs
# Processing Record 9 of Set 9 | saint-augustin
# Processing Record 10 of Set 9 | kuytun
# Processing Record 11 of Set 9 | hasaki
# Processing Record 12 of Set 9 | pontianak
# Processing Record 13 of Set 9 | mecca
# Processing Record 14 of Set 9 | ochakiv
# Processing Record 15 of Set 9 | liberal
# Processing Record 16 of Set 9 | oyama
# Processing Record 17 of Set 9 | germersheim
# Processing Record 18 of Set 9 | kirakira
# Processing Record 19 of Set 9 | skoghall
# Processing Record 20 of Set 9 | vengerovo
# Processing Record 21 of Set 9 | noumea
# Processing Record 22 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 9 | sitka
# Processing Record 24 of Set 9 | makakilo city
# Processing Record 25 of Set 9 | cicuco
# Processing Record 26 of Set 9 | santa maria
# Processing Record 27 of Set 9 | shrewsbury
# Processing Record 28 of Set 9 | changzhou
# Processing Record 29 of Set 9 | posse
# Processing Record 30 of Set 9 | the valley
# Processing Record 31 of Set 9 | kautokeino
# Processing Record 32 of Set 9 | san cristobal
# Processing Record 33 of Set 9 | narasannapeta
# Processing Record 34 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 9 | rosenberg
# Processing Record 36 of Set 9 | jagannathpur
# Processing Record 37 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 9 | harper
# Processing Record 39 of Set 9 | poum
# Processing Record 40 of Set 9 | tangshan
# Processing Record 41 of Set 9 | saint-georges
# Processing Record 42 of Set 9 | nuevitas
# Processing Record 43 of Set 9 | bilibino
# Processing Record 44 of Set 9 | banda aceh
# Processing Record 45 of Set 9 | nelson
# Processing Record 46 of Set 9 | treinta y tres
# Processing Record 47 of Set 9 | zyryanovsk
# Processing Record 48 of Set 9 | ugoofaaru
# Processing Record 49 of Set 9 | sovetskiy
# Processing Record 50 of Set 9 | marsh harbour
# Processing Record 1 of Set 10 | moroni
# Processing Record 2 of Set 10 | karlskoga
# Processing Record 3 of Set 10 | hambantota
# Processing Record 4 of Set 10 | sao luiz gonzaga
# Processing Record 5 of Set 10 | varvoru
# Processing Record 6 of Set 10 | saint anthony
# Processing Record 7 of Set 10 | benguela
# Processing Record 8 of Set 10 | charlestown
# Processing Record 9 of Set 10 | moerai
# Processing Record 10 of Set 10 | cobija
# Processing Record 11 of Set 10 | vadso
# Processing Record 12 of Set 10 | nome
# Processing Record 13 of Set 10 | longkou
# Processing Record 14 of Set 10 | kieta
# Processing Record 15 of Set 10 | san jose
# Processing Record 16 of Set 10 | havelock
# Processing Record 17 of Set 10 | bom jesus
# Processing Record 18 of Set 10 | lasa
# Processing Record 19 of Set 10 | aklavik
# Processing Record 20 of Set 10 | sadao
# Processing Record 21 of Set 10 | bumba
# Processing Record 22 of Set 10 | zhurivka
# Processing Record 23 of Set 10 | rayagada
# Processing Record 24 of Set 10 | skvyra
# Processing Record 25 of Set 10 | atlantic city
# Processing Record 26 of Set 10 | arrecife
# Processing Record 27 of Set 10 | dunhua
# Processing Record 28 of Set 10 | korla
# Processing Record 29 of Set 10 | cidreira
# Processing Record 30 of Set 10 | namibe
# Processing Record 31 of Set 10 | soltsy
# Processing Record 32 of Set 10 | shimoda
# Processing Record 33 of Set 10 | muzhi
# Processing Record 34 of Set 10 | port-gentil
# Processing Record 35 of Set 10 | camacha
# Processing Record 36 of Set 10 | partanna
# Processing Record 37 of Set 10 | phirangipuram
# Processing Record 38 of Set 10 | pangnirtung
# Processing Record 39 of Set 10 | mackay
# Processing Record 40 of Set 10 | sar-e pul
# Processing Record 41 of Set 10 | la ferte-bernard
# Processing Record 42 of Set 10 | itarema
# Processing Record 43 of Set 10 | luganville
# Processing Record 44 of Set 10 | ashland
# Processing Record 45 of Set 10 | tasiilaq
# Processing Record 46 of Set 10 | tupik
# Processing Record 47 of Set 10 | teluk nibung
# Processing Record 48 of Set 10 | boende
# Processing Record 49 of Set 10 | burnie
# Processing Record 50 of Set 10 | udimskiy
# Processing Record 1 of Set 11 | zhob
# Processing Record 2 of Set 11 | chelmsford
# Processing Record 3 of Set 11 | skjervoy
# Processing Record 4 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 5 of Set 11 | belmonte
# Processing Record 6 of Set 11 | lagoa
# Processing Record 7 of Set 11 | bafilo
# Processing Record 8 of Set 11 | kondoa
# Processing Record 9 of Set 11 | kudahuvadhoo
# Processing Record 10 of Set 11 | lavrentiya
# Processing Record 11 of Set 11 | baruun-urt
# Processing Record 12 of Set 11 | potgietersrus
# City not found. Skipping...
# Processing Record 13 of Set 11 | san buenaventura
# Processing Record 14 of Set 11 | ulloa
# Processing Record 15 of Set 11 | mehamn
# Processing Record 16 of Set 11 | half moon bay
# Processing Record 17 of Set 11 | soc trang
# Processing Record 18 of Set 11 | sao gabriel da cachoeira
# Processing Record 19 of Set 11 | collie
# Processing Record 20 of Set 11 | labuhan
# Processing Record 21 of Set 11 | razlog
# Processing Record 22 of Set 11 | prince rupert
# Processing Record 23 of Set 11 | kazachinskoye
# Processing Record 24 of Set 11 | galdar
# Processing Record 25 of Set 11 | fairbanks
# Processing Record 26 of Set 11 | saltillo
# Processing Record 27 of Set 11 | hualmay
# Processing Record 28 of Set 11 | san rafael
# Processing Record 29 of Set 11 | wenzhou
# Processing Record 30 of Set 11 | san luis
# Processing Record 31 of Set 11 | okha
# Processing Record 32 of Set 11 | weligama
# Processing Record 33 of Set 11 | lincoln
# Processing Record 34 of Set 11 | ewa beach
# Processing Record 35 of Set 11 | quatre cocos
# Processing Record 36 of Set 11 | bonthe
# Processing Record 37 of Set 11 | nelson bay
# Processing Record 38 of Set 11 | pinhao
# Processing Record 39 of Set 11 | blagoyevo
# Processing Record 40 of Set 11 | alassio
# Processing Record 41 of Set 11 | chivilcoy
# Processing Record 42 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 11 | santa ana
# Processing Record 44 of Set 11 | aguimes
# Processing Record 45 of Set 11 | oranjemund
# Processing Record 46 of Set 11 | topolcani
# Processing Record 47 of Set 11 | kulachi
# Processing Record 48 of Set 11 | inuvik
# Processing Record 49 of Set 11 | belaya gora
# Processing Record 50 of Set 11 | lodwar
# Processing Record 1 of Set 12 | georgetown
# Processing Record 2 of Set 12 | carutapera
# Processing Record 3 of Set 12 | senmonorom
# City not found. Skipping...
# Processing Record 4 of Set 12 | margate
# Processing Record 5 of Set 12 | yar-sale
# Processing Record 6 of Set 12 | sapucai
# Processing Record 7 of Set 12 | gimli
# Processing Record 8 of Set 12 | donskoye
# Processing Record 9 of Set 12 | port hueneme
# Processing Record 10 of Set 12 | belyy yar
# Processing Record 11 of Set 12 | grand gaube
# Processing Record 12 of Set 12 | kyabe
# Processing Record 13 of Set 12 | beyneu
# Processing Record 14 of Set 12 | nouadhibou
# Processing Record 15 of Set 12 | taltal
# Processing Record 16 of Set 12 | kamenka
# Processing Record 17 of Set 12 | vieste
# Processing Record 18 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 19 of Set 12 | virginia beach
# Processing Record 20 of Set 12 | petit goave
# Processing Record 21 of Set 12 | brainerd
# Processing Record 22 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 23 of Set 12 | lulea
# Processing Record 24 of Set 12 | sur
# Processing Record 25 of Set 12 | kemin
# Processing Record 26 of Set 12 | qarchi gak
# Processing Record 27 of Set 12 | thinadhoo
# Processing Record 28 of Set 12 | naze
# Processing Record 29 of Set 12 | husavik
# Processing Record 30 of Set 12 | trebnje
# Processing Record 31 of Set 12 | vaitape
# Processing Record 32 of Set 12 | lagos
# Processing Record 33 of Set 12 | male
# Processing Record 34 of Set 12 | nara
# Processing Record 35 of Set 12 | tecolutla
# Processing Record 36 of Set 12 | hvolsvollur
# Processing Record 37 of Set 12 | kandrian
# Processing Record 38 of Set 12 | guarapari
# Processing Record 39 of Set 12 | nouakchott
# Processing Record 40 of Set 12 | chabahar
# Processing Record 41 of Set 12 | chibuto
# Processing Record 42 of Set 12 | jumla
# Processing Record 43 of Set 12 | vysoke myto
# Processing Record 44 of Set 12 | pauini
# Processing Record 45 of Set 12 | milingimbi
# City not found. Skipping...
# Processing Record 46 of Set 12 | santiago
# Processing Record 47 of Set 12 | kukushtan
# Processing Record 48 of Set 12 | cayhagan
# Processing Record 49 of Set 12 | vila velha
# Processing Record 50 of Set 12 | tateyama
# Processing Record 1 of Set 13 | gaya
# Processing Record 2 of Set 13 | borba
# Processing Record 3 of Set 13 | moree
# Processing Record 4 of Set 13 | sarakhs
# Processing Record 5 of Set 13 | bulgan
# Processing Record 6 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 13 | salina cruz
# Processing Record 8 of Set 13 | pimentel
# Processing Record 9 of Set 13 | aquiraz
# Processing Record 10 of Set 13 | nkhata bay
# Processing Record 11 of Set 13 | tabuk
# Processing Record 12 of Set 13 | kampong chhnang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 564

# %%
#convert the array of dictionaries to a Pandas DataFrame.
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Atuona  -9.8000 -139.0333    298.44        71          21        6.40
# 1  Port Alfred -33.5906   26.8910    290.33        66           0        4.30
# 2    Cape Town -33.9258   18.4232    294.21        40           0        2.24
# 3   Nanortalik  60.1432  -45.2371    277.47        83         100        4.45
# 4      Mankono   8.0586   -6.1897    295.03        95         100        2.24
#
#   Country                 Date
# 0      PF  2022-06-10 21:41:42
# 1      ZA  2022-06-10 21:41:42
# 2      ZA  2022-06-10 21:38:08
# 3      GL  2022-06-10 21:41:43
# 4      CI  2022-06-10 21:41:43

# %%
#reorder the columns
new_column_order=["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]

# %%
#assign to the dataframe
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0       Atuona      PF  2022-06-10 21:41:42  -9.8000 -139.0333    298.44
# 1  Port Alfred      ZA  2022-06-10 21:41:42 -33.5906   26.8910    290.33
# 2    Cape Town      ZA  2022-06-10 21:38:08 -33.9258   18.4232    294.21
# 3   Nanortalik      GL  2022-06-10 21:41:43  60.1432  -45.2371    277.47
# 4      Mankono      CI  2022-06-10 21:41:43   8.0586   -6.1897    295.03
#
#    Humidity  Cloudiness  Wind Speed
# 0        71          21        6.40
# 1        66           0        4.30
# 2        40           0        2.24
# 3        83         100        4.45
# 4        95         100        2.24

# %%
#create the output file(csv)
output_data_file="weather_data/cities.csv"
#export the city_data into a csv.
city_data_df.to_csv(output_data_file,index_label="City_ID")
