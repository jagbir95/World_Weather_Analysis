# %%
# Import the dependencies.
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
import requests
from config import weather_api_key
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#coordinates

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
#declare the url
url="https://api.openweathermap.org/data/2.5/weather?lat=57&lon=-2.15&appid="+weather_api_key+"&units=imperial"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | umba
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | torbay
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | yenagoa
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | grindavik
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | adrar
# Processing Record 15 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 1 | esperance
# Processing Record 17 of Set 1 | sitka
# Processing Record 18 of Set 1 | umm lajj
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | souillac
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | kawalu
# Processing Record 25 of Set 1 | hobyo
# Processing Record 26 of Set 1 | lakselv
# Processing Record 27 of Set 1 | yabassi
# Processing Record 28 of Set 1 | aksarka
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | skjervoy
# Processing Record 31 of Set 1 | dingle
# Processing Record 32 of Set 1 | aklavik
# Processing Record 33 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 1 | chokurdakh
# Processing Record 35 of Set 1 | viradouro
# Processing Record 36 of Set 1 | gulfport
# Processing Record 37 of Set 1 | tuatapere
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | east london
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | igbaras
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | tanhacu
# Processing Record 46 of Set 1 | luderitz
# Processing Record 47 of Set 1 | ancud
# Processing Record 48 of Set 1 | lata
# Processing Record 49 of Set 1 | charters towers
# Processing Record 50 of Set 1 | nguruka
# Processing Record 1 of Set 2 | saint-pierre
# Processing Record 2 of Set 2 | cidreira
# Processing Record 3 of Set 2 | katsuura
# Processing Record 4 of Set 2 | labuhan
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 2 | itarema
# Processing Record 8 of Set 2 | izumo
# Processing Record 9 of Set 2 | junagadh
# Processing Record 10 of Set 2 | dalbandin
# Processing Record 11 of Set 2 | prado
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | hasaki
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | constitucion
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | tiznit
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | cadillac
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | emirdag
# Processing Record 26 of Set 2 | chuy
# Processing Record 27 of Set 2 | urengoy
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | cairns
# Processing Record 30 of Set 2 | montepuez
# Processing Record 31 of Set 2 | betare oya
# Processing Record 32 of Set 2 | raisen
# Processing Record 33 of Set 2 | puerto escondido
# Processing Record 34 of Set 2 | castanos
# Processing Record 35 of Set 2 | severo-kurilsk
# Processing Record 36 of Set 2 | richards bay
# Processing Record 37 of Set 2 | coquimbo
# Processing Record 38 of Set 2 | shenavan
# Processing Record 39 of Set 2 | huarmey
# Processing Record 40 of Set 2 | kruisfontein
# Processing Record 41 of Set 2 | pangnirtung
# Processing Record 42 of Set 2 | palasa
# Processing Record 43 of Set 2 | castro
# Processing Record 44 of Set 2 | kaitangata
# Processing Record 45 of Set 2 | coffs harbour
# Processing Record 46 of Set 2 | batagay-alyta
# Processing Record 47 of Set 2 | hervey bay
# Processing Record 48 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 2 | college
# Processing Record 50 of Set 2 | valvedditturai
# Processing Record 1 of Set 3 | ambilobe
# Processing Record 2 of Set 3 | vila franca do campo
# Processing Record 3 of Set 3 | mataura
# Processing Record 4 of Set 3 | sisimiut
# Processing Record 5 of Set 3 | botwood
# Processing Record 6 of Set 3 | imperia
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | busselton
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | altay
# Processing Record 12 of Set 3 | santa fe
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | rondonopolis
# Processing Record 15 of Set 3 | geraldton
# Processing Record 16 of Set 3 | tarrafal
# Processing Record 17 of Set 3 | sakaiminato
# Processing Record 18 of Set 3 | sobolevo
# Processing Record 19 of Set 3 | quatre cocos
# Processing Record 20 of Set 3 | airai
# Processing Record 21 of Set 3 | fortuna
# Processing Record 22 of Set 3 | saint george
# Processing Record 23 of Set 3 | kongolo
# Processing Record 24 of Set 3 | isangel
# Processing Record 25 of Set 3 | byron bay
# Processing Record 26 of Set 3 | coihaique
# Processing Record 27 of Set 3 | lasa
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 3 | xiongzhou
# Processing Record 32 of Set 3 | sept-iles
# Processing Record 33 of Set 3 | codrington
# Processing Record 34 of Set 3 | chifeng
# Processing Record 35 of Set 3 | hofn
# Processing Record 36 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 37 of Set 3 | evensk
# Processing Record 38 of Set 3 | sinnamary
# Processing Record 39 of Set 3 | faanui
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | araouane
# Processing Record 42 of Set 3 | trat
# Processing Record 43 of Set 3 | oranjestad
# Processing Record 44 of Set 3 | grand gaube
# Processing Record 45 of Set 3 | zima
# Processing Record 46 of Set 3 | nouadhibou
# Processing Record 47 of Set 3 | mogadishu
# Processing Record 48 of Set 3 | saint-louis
# Processing Record 49 of Set 3 | saint-georges
# Processing Record 50 of Set 3 | provideniya
# Processing Record 1 of Set 4 | beringovskiy
# Processing Record 2 of Set 4 | hohhot
# Processing Record 3 of Set 4 | vostok
# Processing Record 4 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 4 | nemuro
# Processing Record 6 of Set 4 | ribeira grande
# Processing Record 7 of Set 4 | anzio
# Processing Record 8 of Set 4 | oksfjord
# Processing Record 9 of Set 4 | requena
# Processing Record 10 of Set 4 | abha
# Processing Record 11 of Set 4 | porto empedocle
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | mahebourg
# Processing Record 14 of Set 4 | atuona
# Processing Record 15 of Set 4 | charyshskoye
# Processing Record 16 of Set 4 | necochea
# Processing Record 17 of Set 4 | solnechnyy
# Processing Record 18 of Set 4 | khani
# Processing Record 19 of Set 4 | port lincoln
# Processing Record 20 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 4 | yar-sale
# Processing Record 22 of Set 4 | gumdag
# Processing Record 23 of Set 4 | yellowknife
# Processing Record 24 of Set 4 | uravakonda
# Processing Record 25 of Set 4 | komsomolskiy
# Processing Record 26 of Set 4 | amahai
# Processing Record 27 of Set 4 | baboua
# City not found. Skipping...
# Processing Record 28 of Set 4 | baruun-urt
# Processing Record 29 of Set 4 | champerico
# Processing Record 30 of Set 4 | cam ranh
# Processing Record 31 of Set 4 | kununurra
# Processing Record 32 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 4 | coahuayana
# Processing Record 34 of Set 4 | hovd
# Processing Record 35 of Set 4 | eusebio
# Processing Record 36 of Set 4 | inhambane
# Processing Record 37 of Set 4 | trapani
# Processing Record 38 of Set 4 | billings
# Processing Record 39 of Set 4 | samarinda
# Processing Record 40 of Set 4 | talnakh
# Processing Record 41 of Set 4 | moree
# Processing Record 42 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 4 | sortland
# Processing Record 44 of Set 4 | puerto madryn
# Processing Record 45 of Set 4 | clyde river
# Processing Record 46 of Set 4 | salta
# Processing Record 47 of Set 4 | tasiilaq
# Processing Record 48 of Set 4 | half moon bay
# Processing Record 49 of Set 4 | lebu
# Processing Record 50 of Set 4 | sao felix do xingu
# Processing Record 1 of Set 5 | belaya gora
# Processing Record 2 of Set 5 | hearst
# Processing Record 3 of Set 5 | khatanga
# Processing Record 4 of Set 5 | togitsu
# Processing Record 5 of Set 5 | hirara
# Processing Record 6 of Set 5 | huadian
# Processing Record 7 of Set 5 | san quintin
# Processing Record 8 of Set 5 | san jeronimo
# Processing Record 9 of Set 5 | longyearbyen
# Processing Record 10 of Set 5 | sao filipe
# Processing Record 11 of Set 5 | gamba
# Processing Record 12 of Set 5 | atar
# Processing Record 13 of Set 5 | los llanos de aridane
# Processing Record 14 of Set 5 | hithadhoo
# Processing Record 15 of Set 5 | mar del plata
# Processing Record 16 of Set 5 | xuzhou
# Processing Record 17 of Set 5 | izhevskoye
# Processing Record 18 of Set 5 | sampit
# Processing Record 19 of Set 5 | victoria
# Processing Record 20 of Set 5 | tautira
# Processing Record 21 of Set 5 | saskylakh
# Processing Record 22 of Set 5 | monterey
# Processing Record 23 of Set 5 | ranong
# Processing Record 24 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 5 | tiksi
# Processing Record 26 of Set 5 | padang
# Processing Record 27 of Set 5 | cockburn town
# Processing Record 28 of Set 5 | cherskiy
# Processing Record 29 of Set 5 | astana
# Processing Record 30 of Set 5 | manoel urbano
# Processing Record 31 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 32 of Set 5 | lavrentiya
# Processing Record 33 of Set 5 | westport
# Processing Record 34 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 5 | norman wells
# Processing Record 36 of Set 5 | abu dhabi
# Processing Record 37 of Set 5 | saldanha
# Processing Record 38 of Set 5 | moberly
# Processing Record 39 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 5 | biala podlaska
# Processing Record 41 of Set 5 | nosy varika
# Processing Record 42 of Set 5 | beihai
# Processing Record 43 of Set 5 | mount isa
# Processing Record 44 of Set 5 | kualakapuas
# Processing Record 45 of Set 5 | ilulissat
# Processing Record 46 of Set 5 | banda aceh
# Processing Record 47 of Set 5 | abbeville
# Processing Record 48 of Set 5 | khanewal
# Processing Record 49 of Set 5 | georgetown
# Processing Record 50 of Set 5 | vanimo
# Processing Record 1 of Set 6 | sur
# Processing Record 2 of Set 6 | mount gambier
# Processing Record 3 of Set 6 | pevek
# Processing Record 4 of Set 6 | tirano
# Processing Record 5 of Set 6 | hamilton
# Processing Record 6 of Set 6 | parana
# Processing Record 7 of Set 6 | kahului
# Processing Record 8 of Set 6 | kalevala
# Processing Record 9 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 6 | jiblah
# Processing Record 11 of Set 6 | boyolangu
# Processing Record 12 of Set 6 | saurimo
# Processing Record 13 of Set 6 | road town
# Processing Record 14 of Set 6 | sembabule
# Processing Record 15 of Set 6 | flinders
# Processing Record 16 of Set 6 | buckeye
# Processing Record 17 of Set 6 | camacha
# Processing Record 18 of Set 6 | vao
# Processing Record 19 of Set 6 | bambous virieux
# Processing Record 20 of Set 6 | barguzin
# Processing Record 21 of Set 6 | kavieng
# Processing Record 22 of Set 6 | kokstad
# Processing Record 23 of Set 6 | san cristobal
# Processing Record 24 of Set 6 | wakema
# Processing Record 25 of Set 6 | znamenskoye
# Processing Record 26 of Set 6 | kota bahru
# Processing Record 27 of Set 6 | kaeng khoi
# Processing Record 28 of Set 6 | tamayo
# Processing Record 29 of Set 6 | el carmen
# Processing Record 30 of Set 6 | cabo san lucas
# Processing Record 31 of Set 6 | tremedal
# Processing Record 32 of Set 6 | boende
# Processing Record 33 of Set 6 | barkhan
# Processing Record 34 of Set 6 | mandalgovi
# Processing Record 35 of Set 6 | berlevag
# Processing Record 36 of Set 6 | muriwai beach
# Processing Record 37 of Set 6 | lodeynoye pole
# Processing Record 38 of Set 6 | tual
# Processing Record 39 of Set 6 | along
# Processing Record 40 of Set 6 | ondangwa
# Processing Record 41 of Set 6 | bargarh
# Processing Record 42 of Set 6 | nortelandia
# Processing Record 43 of Set 6 | canon city
# Processing Record 44 of Set 6 | nivala
# Processing Record 45 of Set 6 | dumas
# Processing Record 46 of Set 6 | buala
# Processing Record 47 of Set 6 | kamiichi
# Processing Record 48 of Set 6 | borogontsy
# Processing Record 49 of Set 6 | bengkulu
# Processing Record 50 of Set 6 | cheyenne
# Processing Record 1 of Set 7 | krasnoselkup
# Processing Record 2 of Set 7 | vardo
# Processing Record 3 of Set 7 | juneau
# Processing Record 4 of Set 7 | aviles
# Processing Record 5 of Set 7 | san juan
# Processing Record 6 of Set 7 | tucuma
# Processing Record 7 of Set 7 | bairiki
# Processing Record 8 of Set 7 | jacksonville
# Processing Record 9 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 7 | ust-kuyga
# Processing Record 11 of Set 7 | miyako
# Processing Record 12 of Set 7 | moerai
# Processing Record 13 of Set 7 | lorengau
# Processing Record 14 of Set 7 | kytlym
# City not found. Skipping...
# Processing Record 15 of Set 7 | waipawa
# Processing Record 16 of Set 7 | bud
# Processing Record 17 of Set 7 | adra
# Processing Record 18 of Set 7 | balakhta
# Processing Record 19 of Set 7 | aswan
# Processing Record 20 of Set 7 | plettenberg bay
# Processing Record 21 of Set 7 | comodoro rivadavia
# Processing Record 22 of Set 7 | ecatepec
# Processing Record 23 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | las torres de cotillas
# Processing Record 27 of Set 7 | turka
# Processing Record 28 of Set 7 | ust-omchug
# Processing Record 29 of Set 7 | ajuchitlan
# Processing Record 30 of Set 7 | tomatlan
# Processing Record 31 of Set 7 | nador
# Processing Record 32 of Set 7 | bathsheba
# Processing Record 33 of Set 7 | gisborne
# Processing Record 34 of Set 7 | magadi
# Processing Record 35 of Set 7 | taoudenni
# Processing Record 36 of Set 7 | banjar
# Processing Record 37 of Set 7 | mirabad
# Processing Record 38 of Set 7 | pierre
# Processing Record 39 of Set 7 | misratah
# Processing Record 40 of Set 7 | ocumare del tuy
# Processing Record 41 of Set 7 | roald
# Processing Record 42 of Set 7 | umri
# Processing Record 43 of Set 7 | ciro marina
# Processing Record 44 of Set 7 | nuuk
# Processing Record 45 of Set 7 | kismayo
# Processing Record 46 of Set 7 | baykit
# Processing Record 47 of Set 7 | kloulklubed
# Processing Record 48 of Set 7 | haines junction
# Processing Record 49 of Set 7 | zyryanka
# Processing Record 50 of Set 7 | ozernovskiy
# Processing Record 1 of Set 8 | aykhal
# Processing Record 2 of Set 8 | nanortalik
# Processing Record 3 of Set 8 | iqaluit
# Processing Record 4 of Set 8 | langxiang
# Processing Record 5 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 8 | panaba
# Processing Record 7 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 8 of Set 8 | concordia
# Processing Record 9 of Set 8 | kavaratti
# Processing Record 10 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 8 | poum
# Processing Record 12 of Set 8 | candido mendes
# Processing Record 13 of Set 8 | presque isle
# Processing Record 14 of Set 8 | impfondo
# Processing Record 15 of Set 8 | markova
# Processing Record 16 of Set 8 | west odessa
# Processing Record 17 of Set 8 | kolpashevo
# Processing Record 18 of Set 8 | carauari
# Processing Record 19 of Set 8 | namatanai
# Processing Record 20 of Set 8 | high level
# Processing Record 21 of Set 8 | kysyl-syr
# Processing Record 22 of Set 8 | quelimane
# Processing Record 23 of Set 8 | san rafael
# Processing Record 24 of Set 8 | touros
# Processing Record 25 of Set 8 | voyvozh
# Processing Record 26 of Set 8 | lompoc
# Processing Record 27 of Set 8 | constantine
# Processing Record 28 of Set 8 | tarakan
# Processing Record 29 of Set 8 | ashqelon
# Processing Record 30 of Set 8 | bissora
# Processing Record 31 of Set 8 | namibe
# Processing Record 32 of Set 8 | liverpool
# Processing Record 33 of Set 8 | pipar
# Processing Record 34 of Set 8 | aleksandrov gay
# Processing Record 35 of Set 8 | maldonado
# Processing Record 36 of Set 8 | kisangani
# Processing Record 37 of Set 8 | makakilo city
# Processing Record 38 of Set 8 | karaton
# Processing Record 39 of Set 8 | avera
# Processing Record 40 of Set 8 | ebolowa
# Processing Record 41 of Set 8 | lagoa
# Processing Record 42 of Set 8 | port blair
# Processing Record 43 of Set 8 | jurado
# Processing Record 44 of Set 8 | guerrero negro
# Processing Record 45 of Set 8 | ayan
# Processing Record 46 of Set 8 | antofagasta
# Processing Record 47 of Set 8 | bergen
# Processing Record 48 of Set 8 | alice springs
# Processing Record 49 of Set 8 | carutapera
# Processing Record 50 of Set 8 | druzhba
# Processing Record 1 of Set 9 | lensk
# Processing Record 2 of Set 9 | sorong
# Processing Record 3 of Set 9 | arlit
# Processing Record 4 of Set 9 | at-bashi
# Processing Record 5 of Set 9 | caxias
# Processing Record 6 of Set 9 | leningradskiy
# Processing Record 7 of Set 9 | wabag
# Processing Record 8 of Set 9 | arosa
# Processing Record 9 of Set 9 | champua
# Processing Record 10 of Set 9 | zonguldak
# Processing Record 11 of Set 9 | amga
# Processing Record 12 of Set 9 | dawson creek
# Processing Record 13 of Set 9 | kirillov
# Processing Record 14 of Set 9 | drayton valley
# Processing Record 15 of Set 9 | springdale
# Processing Record 16 of Set 9 | saryg-sep
# Processing Record 17 of Set 9 | alvorada
# Processing Record 18 of Set 9 | kulunda
# Processing Record 19 of Set 9 | whitehorse
# Processing Record 20 of Set 9 | lhokseumawe
# Processing Record 21 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 9 | tolaga bay
# Processing Record 23 of Set 9 | sechura
# Processing Record 24 of Set 9 | anadyr
# Processing Record 25 of Set 9 | rocha
# Processing Record 26 of Set 9 | yining
# Processing Record 27 of Set 9 | sabang
# Processing Record 28 of Set 9 | evanton
# Processing Record 29 of Set 9 | amapa
# Processing Record 30 of Set 9 | stephenville
# Processing Record 31 of Set 9 | bredy
# Processing Record 32 of Set 9 | duzici
# City not found. Skipping...
# Processing Record 33 of Set 9 | peniche
# Processing Record 34 of Set 9 | abu samrah
# Processing Record 35 of Set 9 | mulanje
# Processing Record 36 of Set 9 | beian
# Processing Record 37 of Set 9 | tanout
# Processing Record 38 of Set 9 | cayenne
# Processing Record 39 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 40 of Set 9 | loubomo
# Processing Record 41 of Set 9 | marfino
# Processing Record 42 of Set 9 | glyadyanskoye
# Processing Record 43 of Set 9 | petropavlovka
# Processing Record 44 of Set 9 | parabel
# Processing Record 45 of Set 9 | alofi
# Processing Record 46 of Set 9 | predivinsk
# Processing Record 47 of Set 9 | rio grande
# Processing Record 48 of Set 9 | asfi
# Processing Record 49 of Set 9 | mitsamiouli
# Processing Record 50 of Set 9 | fonte boa
# Processing Record 1 of Set 10 | riyadh
# Processing Record 2 of Set 10 | arman
# Processing Record 3 of Set 10 | klaksvik
# Processing Record 4 of Set 10 | karratha
# Processing Record 5 of Set 10 | bahia blanca
# Processing Record 6 of Set 10 | maxixe
# Processing Record 7 of Set 10 | durban
# Processing Record 8 of Set 10 | maniitsoq
# Processing Record 9 of Set 10 | leeton
# Processing Record 10 of Set 10 | jackson
# Processing Record 11 of Set 10 | chapleau
# Processing Record 12 of Set 10 | macau
# Processing Record 13 of Set 10 | bonavista
# Processing Record 14 of Set 10 | chicama
# Processing Record 15 of Set 10 | vilyuysk
# Processing Record 16 of Set 10 | sao joao da barra
# Processing Record 17 of Set 10 | calabaca
# Processing Record 18 of Set 10 | ullapool
# Processing Record 19 of Set 10 | presidencia roque saenz pena
# Processing Record 20 of Set 10 | montivilliers
# Processing Record 21 of Set 10 | saint anthony
# Processing Record 22 of Set 10 | lithgow
# Processing Record 23 of Set 10 | inuvik
# Processing Record 24 of Set 10 | quime
# Processing Record 25 of Set 10 | chanute
# Processing Record 26 of Set 10 | mezen
# Processing Record 27 of Set 10 | marang
# Processing Record 28 of Set 10 | srednekolymsk
# Processing Record 29 of Set 10 | qingdao
# Processing Record 30 of Set 10 | sungairaya
# Processing Record 31 of Set 10 | folkestone
# Processing Record 32 of Set 10 | lazaro cardenas
# Processing Record 33 of Set 10 | sosnytsya
# Processing Record 34 of Set 10 | hambantota
# Processing Record 35 of Set 10 | acapulco
# Processing Record 36 of Set 10 | kathu
# Processing Record 37 of Set 10 | luba
# Processing Record 38 of Set 10 | wattegama
# Processing Record 39 of Set 10 | bunia
# Processing Record 40 of Set 10 | okahandja
# Processing Record 41 of Set 10 | aktash
# Processing Record 42 of Set 10 | tyup
# Processing Record 43 of Set 10 | husavik
# Processing Record 44 of Set 10 | shache
# Processing Record 45 of Set 10 | cheremshan
# Processing Record 46 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 47 of Set 10 | toora-khem
# Processing Record 48 of Set 10 | san antonio del norte
# Processing Record 49 of Set 10 | schwedt
# Processing Record 50 of Set 10 | nenjiang
# Processing Record 1 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 11 | kaeo
# Processing Record 3 of Set 11 | mackenzie
# Processing Record 4 of Set 11 | murray bridge
# Processing Record 5 of Set 11 | arcachon
# Processing Record 6 of Set 11 | madrid
# Processing Record 7 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 11 | nome
# Processing Record 9 of Set 11 | bonthe
# Processing Record 10 of Set 11 | sibolga
# Processing Record 11 of Set 11 | kigoma
# Processing Record 12 of Set 11 | progreso
# Processing Record 13 of Set 11 | fond du lac
# Processing Record 14 of Set 11 | providencia
# Processing Record 15 of Set 11 | grabovo
# Processing Record 16 of Set 11 | atbasar
# Processing Record 17 of Set 11 | novobirilyussy
# Processing Record 18 of Set 11 | seymchan
# Processing Record 19 of Set 11 | kopanskaya
# Processing Record 20 of Set 11 | hami
# Processing Record 21 of Set 11 | port moresby
# Processing Record 22 of Set 11 | barabinsk
# Processing Record 23 of Set 11 | santo antonio do sudoeste
# Processing Record 24 of Set 11 | eydhafushi
# Processing Record 25 of Set 11 | basco
# Processing Record 26 of Set 11 | sacramento
# Processing Record 27 of Set 11 | punalur
# Processing Record 28 of Set 11 | jaen
# Processing Record 29 of Set 11 | sawakin
# Processing Record 30 of Set 11 | sambava
# Processing Record 31 of Set 11 | sedan
# Processing Record 32 of Set 11 | chumikan
# Processing Record 33 of Set 11 | mormugao
# Processing Record 34 of Set 11 | chegdomyn
# Processing Record 35 of Set 11 | ballina
# Processing Record 36 of Set 11 | ambon
# Processing Record 37 of Set 11 | pingliang
# Processing Record 38 of Set 11 | dwarka
# Processing Record 39 of Set 11 | kailua
# Processing Record 40 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 41 of Set 11 | oistins
# Processing Record 42 of Set 11 | egvekinot
# Processing Record 43 of Set 11 | buchanan
# Processing Record 44 of Set 11 | shitanjing
# Processing Record 45 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 11 | rawson
# Processing Record 47 of Set 11 | muros
# Processing Record 48 of Set 11 | port hedland
# Processing Record 49 of Set 11 | kurchum
# Processing Record 50 of Set 11 | manaus
# Processing Record 1 of Set 12 | houlton
# Processing Record 2 of Set 12 | lalmohan
# Processing Record 3 of Set 12 | tsukumi
# Processing Record 4 of Set 12 | dalian
# Processing Record 5 of Set 12 | honiara
# Processing Record 6 of Set 12 | bolshaya murta
# City not found. Skipping...
# Processing Record 7 of Set 12 | idah
# Processing Record 8 of Set 12 | sioux lookout
# Processing Record 9 of Set 12 | zhitikara
# City not found. Skipping...
# Processing Record 10 of Set 12 | dubbo
# Processing Record 11 of Set 12 | thinadhoo
# Processing Record 12 of Set 12 | tilichiki
# Processing Record 13 of Set 12 | takoradi
# Processing Record 14 of Set 12 | upernavik
# Processing Record 15 of Set 12 | san pelayo
# Processing Record 16 of Set 12 | buraydah
# Processing Record 17 of Set 12 | mashhad
# Processing Record 18 of Set 12 | teya
# Processing Record 19 of Set 12 | cururupu
# Processing Record 20 of Set 12 | salalah
# Processing Record 21 of Set 12 | korla
# Processing Record 22 of Set 12 | beroroha
# Processing Record 23 of Set 12 | imeni poliny osipenko
# Processing Record 24 of Set 12 | savannah bight
# Processing Record 25 of Set 12 | port macquarie
# Processing Record 26 of Set 12 | bima
# Processing Record 27 of Set 12 | chunoyar
# Processing Record 28 of Set 12 | merke
# Processing Record 29 of Set 12 | shimoda
# Processing Record 30 of Set 12 | deputatskiy
# Processing Record 31 of Set 12 | axim
# Processing Record 32 of Set 12 | onega
# Processing Record 33 of Set 12 | kyshtovka
# Processing Record 34 of Set 12 | oktyabrskoye
# Processing Record 35 of Set 12 | saint-augustin
# Processing Record 36 of Set 12 | narsaq
# Processing Record 37 of Set 12 | doha
# Processing Record 38 of Set 12 | nongstoin
# Processing Record 39 of Set 12 | gimli
# Processing Record 40 of Set 12 | seoul
# Processing Record 41 of Set 12 | boca do acre
# Processing Record 42 of Set 12 | rockport
# Processing Record 43 of Set 12 | praia da vitoria
# Processing Record 44 of Set 12 | erdenet
# Processing Record 45 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 46 of Set 12 | tocopilla
# Processing Record 47 of Set 12 | ossora
# Processing Record 48 of Set 12 | chiredzi
# Processing Record 49 of Set 12 | kalanchak
# Processing Record 50 of Set 12 | fairbanks
# Processing Record 1 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 13 | centralia
# Processing Record 3 of Set 13 | maragogi
# Processing Record 4 of Set 13 | rawlins
# Processing Record 5 of Set 13 | kaka
# Processing Record 6 of Set 13 | mehamn
# Processing Record 7 of Set 13 | turayf
# Processing Record 8 of Set 13 | beloha
# Processing Record 9 of Set 13 | shirokiy
# Processing Record 10 of Set 13 | bloomingdale
# Processing Record 11 of Set 13 | anloga
# Processing Record 12 of Set 13 | simao
# Processing Record 13 of Set 13 | balakhninskiy
# Processing Record 14 of Set 13 | nizwa
# Processing Record 15 of Set 13 | zacatlan
# Processing Record 16 of Set 13 | luanda
# Processing Record 17 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 18 of Set 13 | bardiyah
# Processing Record 19 of Set 13 | quang ngai
# Processing Record 20 of Set 13 | novokizhinginsk
# Processing Record 21 of Set 13 | manyava
# Processing Record 22 of Set 13 | amla
# Processing Record 23 of Set 13 | boddam
# Processing Record 24 of Set 13 | meridian
# Processing Record 25 of Set 13 | north platte
# Processing Record 26 of Set 13 | bremen
# Processing Record 27 of Set 13 | kotma
# Processing Record 28 of Set 13 | marawi
# Processing Record 29 of Set 13 | sarh
# Processing Record 30 of Set 13 | ust-nera
# Processing Record 31 of Set 13 | phanom thuan
# Processing Record 32 of Set 13 | strzelce krajenskie
# Processing Record 33 of Set 13 | louga
# Processing Record 34 of Set 13 | puertollano
# Processing Record 35 of Set 13 | brae
# Processing Record 36 of Set 13 | dawei
# Processing Record 37 of Set 13 | vila
# Processing Record 38 of Set 13 | azanka
# Processing Record 39 of Set 13 | tessalit
# Processing Record 40 of Set 13 | aripuana
# Processing Record 41 of Set 13 | kieta
# Processing Record 42 of Set 13 | longjiang
# Processing Record 43 of Set 13 | cruzeiro do sul
# Processing Record 44 of Set 13 | mayor pablo lagerenza
# Processing Record 45 of Set 13 | baiyin
# Processing Record 46 of Set 13 | remerschen
# Processing Record 47 of Set 13 | iskateley
# Processing Record 48 of Set 13 | nyurba
# Processing Record 49 of Set 13 | san rafael del sur
# Processing Record 50 of Set 13 | biak
# Processing Record 1 of Set 14 | vila velha
# Processing Record 2 of Set 14 | finnsnes
# Processing Record 3 of Set 14 | malacacheta
# Processing Record 4 of Set 14 | neyshabur
# Processing Record 5 of Set 14 | saint-honore
# Processing Record 6 of Set 14 | teguldet
# Processing Record 7 of Set 14 | mahibadhoo
# Processing Record 8 of Set 14 | marsa matruh
# Processing Record 9 of Set 14 | mazara del vallo
# Processing Record 10 of Set 14 | llanes
# Processing Record 11 of Set 14 | praia
# Processing Record 12 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 14 | petrovskoye
# Processing Record 14 of Set 14 | angra
# City not found. Skipping...
# Processing Record 15 of Set 14 | pandan
# Processing Record 16 of Set 14 | trenggalek
# Processing Record 17 of Set 14 | denpasar
# Processing Record 18 of Set 14 | miracema do tocantins
# Processing Record 19 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 14 | broome
# Processing Record 21 of Set 14 | eenhana
# Processing Record 22 of Set 14 | zhetybay
# City not found. Skipping...
# Processing Record 23 of Set 14 | scarborough
# Processing Record 24 of Set 14 | xadani
# City not found. Skipping...
# Processing Record 25 of Set 14 | berbera
# Processing Record 26 of Set 14 | adamovka
# Processing Record 27 of Set 14 | leshan
# Processing Record 28 of Set 14 | achiotal
# City not found. Skipping...
# Processing Record 29 of Set 14 | bertoua
# Processing Record 30 of Set 14 | nelson bay
# Processing Record 31 of Set 14 | palana
# Processing Record 32 of Set 14 | iquitos
# Processing Record 33 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 34 of Set 14 | damietta
# Processing Record 35 of Set 14 | zhuanghe
# Processing Record 36 of Set 14 | marondera
# Processing Record 37 of Set 14 | chengde
# Processing Record 38 of Set 14 | taruma
# Processing Record 39 of Set 14 | iralaya
# Processing Record 40 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 41 of Set 14 | manta
# Processing Record 42 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 14 | helong
# Processing Record 44 of Set 14 | ampanihy
# Processing Record 45 of Set 14 | tucuman
# Processing Record 46 of Set 14 | santiago
# Processing Record 47 of Set 14 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 14 | tungkang
# City not found. Skipping...
# Processing Record 49 of Set 14 | gallup
# Processing Record 50 of Set 14 | maltahohe
# Processing Record 1 of Set 15 | villamontes
# Processing Record 2 of Set 15 | waidhofen
# Processing Record 3 of Set 15 | ouesso
# Processing Record 4 of Set 15 | port hardy
# Processing Record 5 of Set 15 | ilhabela
# Processing Record 6 of Set 15 | ripoll
# Processing Record 7 of Set 15 | staroye drozhzhanoye
# Processing Record 8 of Set 15 | tyukhtet
# Processing Record 9 of Set 15 | barranca
# Processing Record 10 of Set 15 | nsanje
# Processing Record 11 of Set 15 | nacala
# Processing Record 12 of Set 15 | ostrovnoy
# Processing Record 13 of Set 15 | manzanillo
# Processing Record 14 of Set 15 | sola
# Processing Record 15 of Set 15 | fort nelson
# Processing Record 16 of Set 15 | gusau
# Processing Record 17 of Set 15 | belogorsk
# Processing Record 18 of Set 15 | alta floresta
# Processing Record 19 of Set 15 | kempsey
# Processing Record 20 of Set 15 | plymouth
# Processing Record 21 of Set 15 | gizo
# Processing Record 22 of Set 15 | pisco
# Processing Record 23 of Set 15 | san carlos
# Processing Record 24 of Set 15 | dzhebariki-khaya
# Processing Record 25 of Set 15 | jacareacanga
# Processing Record 26 of Set 15 | bubaque
# Processing Record 27 of Set 15 | ushtobe
# Processing Record 28 of Set 15 | kingman
# Processing Record 29 of Set 15 | zhanaozen
# Processing Record 30 of Set 15 | san ramon
# Processing Record 31 of Set 15 | maamba
# Processing Record 32 of Set 15 | coronon
# Processing Record 33 of Set 15 | irbeyskoye
# Processing Record 34 of Set 15 | san vicente
# Processing Record 35 of Set 15 | sal rei
# Processing Record 36 of Set 15 | khandagayty
# Processing Record 37 of Set 15 | sakakah
# Processing Record 38 of Set 15 | broken hill
# Processing Record 39 of Set 15 | ketchikan
# Processing Record 40 of Set 15 | port-cartier
# Processing Record 41 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 42 of Set 15 | opuwo
# Processing Record 43 of Set 15 | tongchuan
# Processing Record 44 of Set 15 | ahipara
# Processing Record 45 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 46 of Set 15 | dzilam gonzalez
# Processing Record 47 of Set 15 | portland
# Processing Record 48 of Set 15 | aksu
# Processing Record 49 of Set 15 | ichinohe
# Processing Record 50 of Set 15 | a
# City not found. Skipping...
# Processing Record 1 of Set 16 | petropavlivka
# Processing Record 2 of Set 16 | khormuj
# City not found. Skipping...
# Processing Record 3 of Set 16 | dubrovnik
# Processing Record 4 of Set 16 | bokspits
# City not found. Skipping...
# Processing Record 5 of Set 16 | roebourne
# Processing Record 6 of Set 16 | horsham
# Processing Record 7 of Set 16 | ukiah
# Processing Record 8 of Set 16 | fare
# Processing Record 9 of Set 16 | besuki
# Processing Record 10 of Set 16 | syracuse
# Processing Record 11 of Set 16 | olovyannaya
# Processing Record 12 of Set 16 | mayo
# Processing Record 13 of Set 16 | kandrian
# Processing Record 14 of Set 16 | stropkov
# Processing Record 15 of Set 16 | tupancireta
# Processing Record 16 of Set 16 | burica
# City not found. Skipping...
# Processing Record 17 of Set 16 | tambilil
# Processing Record 18 of Set 16 | khanpur
# Processing Record 19 of Set 16 | payo
# Processing Record 20 of Set 16 | cumaribo
# City not found. Skipping...
# Processing Record 21 of Set 16 | coalinga
# Processing Record 22 of Set 16 | batemans bay
# Processing Record 23 of Set 16 | ocean city
# Processing Record 24 of Set 16 | oxford
# Processing Record 25 of Set 16 | pontianak
# Processing Record 26 of Set 16 | abonnema
# Processing Record 27 of Set 16 | liuhe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 716

# %%
#convert the array of dictionaries to a pandas dataframe
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Umba  66.6871   34.3429     46.49        93         100
# 1          Hilo  19.7297 -155.0900     73.62        85         100
# 2        Torbay  47.6666  -52.7314     68.88        60          20
# 3        Avarua -21.2078 -159.7750     73.45        83          29
# 4  Punta Arenas -53.1500  -70.9167     39.31        70          40
#
#    Wind Speed Country Current Description
# 0       15.41      RU          light rain
# 1        1.99      US     overcast clouds
# 2       12.66      CA          few clouds
# 3        3.44      CK    scattered clouds
# 4       16.11      CL    scattered clouds

# %%
#Reorder the columns
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
#assign to the dataframe
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Umba      RU  66.6871   34.3429     46.49        93         100
# 1          Hilo      US  19.7297 -155.0900     73.62        85         100
# 2        Torbay      CA  47.6666  -52.7314     68.88        60          20
# 3        Avarua      CK -21.2078 -159.7750     73.45        83          29
# 4  Punta Arenas      CL -53.1500  -70.9167     39.31        70          40
#
#    Wind Speed Current Description
# 0       15.41          light rain
# 1        1.99     overcast clouds
# 2       12.66          few clouds
# 3        3.44    scattered clouds
# 4       16.11    scattered clouds

# %%
#create the output file(csv)
output_data_file="WeatherPy_Database.csv"
#export the city_data into a csv.
city_data_df.to_csv(output_data_file,index_label="City_ID")
